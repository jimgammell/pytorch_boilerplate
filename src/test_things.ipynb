# %%
from datasets.ascad.ascadv2 import ASCADv2, ASCADv2_Targets
from datasets.datamodule import DataModule

# %%
dataset = ASCADv2(r'/mnt/hdd/jgammell/Desktop/leakage_localization/downloads/ascadv2', target=ASCADv2_Targets.FULL)
